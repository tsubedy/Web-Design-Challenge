# %%
import pandas as pd
df = pd.read_csv('./Resources/city_weather_data.csv')

df = pd.DataFrame(df, columns = ["City", "Country", "Lat", "lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"])

dataset = df.to_html()
dataset
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Country</th>\n      <th>Lat</th>\n      <th>lng</th>\n      <th>Max Temp</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>tuktoyaktuk</td>\n      <td>CA</td>\n      <td>69.4541</td>\n      <td>-133.0374</td>\n      <td>54.66</td>\n      <td>58.0</td>\n      <td>100.0</td>\n      <td>8.50</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>qaanaaq</td>\n      <td>GL</td>\n      <td>77.4840</td>\n      <td>-69.3632</td>\n      <td>40.59</td>\n      <td>100.0</td>\n      <td>100.0</td>\n      <td>3.53</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>flinders</td>\n      <td>AU</td>\n      <td>-34.5833</td>\n      <td>150.8552</td>\n      <td>65.05</td>\n      <td>46.0</td>\n      <td>33.0</td>\n      <td>5.99</td>\n    </tr>\n    <tr>\n   
# ...

# %%
df.to_html('dataset.html')
